# %%
import pandas as pd

# %%
df = pd.read_csv('VOTER_Survey_December16_Release1.csv')
df.head()
# Out:
#    case_identifier    weight  PARTY_AGENDAS_rand_2016  pp_primary16_2016  \
# 0              779  0.358213                        2                  1
# 1             2108  0.562867                        2                  2
# 2             2597  0.552138                        2                  1
# 3             4148  0.207591                        1                  1
# 4             4460  0.333729                        2                  2
#
#    pp_demprim16_2016  pp_repprim16_2016  inputstate_2016  izip_2016  \
# 0                1.0                NaN                6      94952
# 1                NaN                1.0                4      85298
# 2                1.0                NaN               55      54904
# 3                3.0                NaN               40      74104
# 4                NaN                4.0               48      78253
#
#    votereg2_2016  votereg_f_2016         ...          \
# 0              1             1.0         ...
# ...
