# %%
import pandas as pd
import geocoder

# %%
df = pd.read_csv("terrorism.csv")
df.head()
# Out:
#        country  killed  wounded                region
# 0  Afghanistan    6119   6485.0                  Asia
# 1      Albania       0      0.0       Europe & Russia
# 2      Algeria       9      2.0  Africa & Middle East
# 3       Angola       0      0.0  Africa & Middle East
# 4    Argentina       0      2.0         South America

# %%
def geocode(country):
    g = geocoder.google(country, key='AIzaSyC9ATX-9ZQD5BoGff0mC6HU0hw7hUlKvN0')
    return pd.Series({
        'lat': g.lat,
        'lng': g.lng
    })

# %%
coords = df.country.apply(geocode)
coords
# Out:
#            lat         lng
# 0    33.939110   67.709953
# 1    41.153332   20.168331
# 2    28.033886    1.659626
# 3   -11.202692   17.873887
# 4   -38.416097  -63.616672
# 5    40.069099   45.038189
# 6   -25.274398  133.775136
# 7    47.516231   14.550072
# 8    40.143105   47.576927
# 9    26.066700   50.557700
# 10   23.684994   90.356331
# 11   50.503887    4.469936
# 12  -14.235004  -51.925280
# 13   42.733883   25.485830
# 14   12.238333   -1.561593
# 15   -3.373056   29.918886
# 16    7.369722   12.354722
# 17   56.130366 -106.346771
# 18    6.611111   20.939444
# 19   15.454166   18.732207
# 20  -35.675147  -71.542969
# 21   35.861660  104.195397
# 22    4.570868  -74.297333
# 23   35.126413   33.429859
# 24   49.817492   15.472962
# 25   -4.038333   21.758664
# 26   56.263920    9.501785
# 27   -1.831239  -78.183406
# 28   26.820553   30.802498
# 29    9.145000   40.489673
# ..         ...         ...
# 78   -0.228021   15.827659
# 79   61.524010  105.318756
# ...

# %%
df.join(coords).to_csv("terrorism-coords.csv", index=False)
