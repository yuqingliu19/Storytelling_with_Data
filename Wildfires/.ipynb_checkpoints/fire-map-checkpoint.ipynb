# %%
import pandas as pd
import geopandas as gpd
from shapely.geometry import Point
from shapely.geometry import Polygon
from matplotlib.colors import LinearSegmentedColormap
import matplotlib.pyplot as plt
% matplotlib inline

# %%
states = gpd.read_file('us_eco_l3.shp')
states.head()
# Out:
#                         L1_KEY                         L2_KEY          L3_KEY  \
# 0  7  MARINE WEST COAST FOREST  7.1  MARINE WEST COAST FOREST  1  Coast Range
# 1  7  MARINE WEST COAST FOREST  7.1  MARINE WEST COAST FOREST  1  Coast Range
# 2  7  MARINE WEST COAST FOREST  7.1  MARINE WEST COAST FOREST  1  Coast Range
# 3  7  MARINE WEST COAST FOREST  7.1  MARINE WEST COAST FOREST  1  Coast Range
# 4  7  MARINE WEST COAST FOREST  7.1  MARINE WEST COAST FOREST  1  Coast Range
#
#   NA_L1CODE                 NA_L1NAME NA_L2CODE                 NA_L2NAME  \
# 0         7  MARINE WEST COAST FOREST       7.1  MARINE WEST COAST FOREST
# 1         7  MARINE WEST COAST FOREST       7.1  MARINE WEST COAST FOREST
# 2         7  MARINE WEST COAST FOREST       7.1  MARINE WEST COAST FOREST
# 3         7  MARINE WEST COAST FOREST       7.1  MARINE WEST COAST FOREST
# 4         7  MARINE WEST COAST FOREST       7.1  MARINE WEST COAST FOREST
#
#   NA_L3CODE    NA_L3NAME    Shape_Area     Shape_Leng US_L3CODE    US_L3NAME  \
# 0     7.1.8  Coast Range  1.872044e+09  312708.089755         1  Coast Range
# 1     7.1.8  Coast Range  6.470114e+03     405.107034         1  Coast Range
# 2     7.1.8  Coast Range  4.503063e+05    6693.388907         1  Coast Range
# 3     7.1.8  Coast Range  2.298740e+03     186.667132         1  Coast Range
# 4     7.1.8  Coast Range  1.898114e+03     239.131689         1  Coast Range
#
#                                             geometry
# 0  POLYGON ((-2284145.6458 1942003.8598, -2284260...
# 1  POLYGON ((-2326859.903999999 1961336.2543, -23...
# 2  POLYGON ((-2326706.4253 1962413.5469, -2326701...
# 3  POLYGON ((-2328276.727 1965731.5141, -2328270....
# 4  POLYGON ((-2332682.747500001 1971271.4419, -23...

# %%
df = pd.read_csv('fire-events.csv')
df.head()
# Out:
#                  fire_id  year  month  day     lat    long  acres_burned  \
# 0  AL3038308812219980404  1998      4    4  30.383 -88.122           705
# 1  AL3041008830120050916  2005      9   16  30.410 -88.301          2914
# 2  AL3067208833720050207  2005      2    7  30.672 -88.337           696
# 3  AL3105208777220050211  2005      2   11  31.052 -87.772          7334
# 4  AL3110108837320050218  2005      2   18  31.101 -88.373           757
#
#                 na_l3name                                          na_l2name  \
# 0  Southern Coastal Plain  MISSISSIPPI ALLUVIAL AND SOUTHEAST USA COASTAL...
# 1  Southern Coastal Plain  MISSISSIPPI ALLUVIAL AND SOUTHEAST USA COASTAL...
# 2     Southeastern Plains                            SOUTHEASTERN USA PLAINS
# 3     Southeastern Plains                            SOUTHEASTERN USA PLAINS
# 4     Southeastern Plains                            SOUTHEASTERN USA PLAINS
#
#                    na_l1name yearmonth  mean_potential_et  total_precip  \
# 0  EASTERN TEMPERATE FORESTS   1998-04           4.757972     50.624569
# 1  EASTERN TEMPERATE FORESTS   2005-09           4.952767     90.424602
# 2  EASTERN TEMPERATE FORESTS   2005-02           2.275852    110.091752
# 3  EASTERN TEMPERATE FORESTS   2005-02           2.275852    110.091752
# 4  EASTERN TEMPERATE FORESTS   2005-02           2.275852    110.091752
#
#    max_air_temp  mean_wind_speed
# 0    299.639977         4.281175
# 1    305.166767         3.975596
# 2    289.275777         4.016748
# 3    289.275777         4.016748
# 4    289.275777         4.016748

# %%
def make_point(row):
    return Point(row.long, row.lat)
points = df.apply(make_point, axis=1)
df = gpd.GeoDataFrame(df, geometry=points)
df.crs = {'init': 'epsg:4326'}
df.head()
# Out:
#                  fire_id  year  month  day     lat    long  acres_burned  \
# 0  AL3038308812219980404  1998      4    4  30.383 -88.122           705
# 1  AL3041008830120050916  2005      9   16  30.410 -88.301          2914
# 2  AL3067208833720050207  2005      2    7  30.672 -88.337           696
# 3  AL3105208777220050211  2005      2   11  31.052 -87.772          7334
# 4  AL3110108837320050218  2005      2   18  31.101 -88.373           757
#
#                 na_l3name                                          na_l2name  \
# 0  Southern Coastal Plain  MISSISSIPPI ALLUVIAL AND SOUTHEAST USA COASTAL...
# 1  Southern Coastal Plain  MISSISSIPPI ALLUVIAL AND SOUTHEAST USA COASTAL...
# 2     Southeastern Plains                            SOUTHEASTERN USA PLAINS
# 3     Southeastern Plains                            SOUTHEASTERN USA PLAINS
# 4     Southeastern Plains                            SOUTHEASTERN USA PLAINS
#
#                    na_l1name yearmonth  mean_potential_et  total_precip  \
# 0  EASTERN TEMPERATE FORESTS   1998-04           4.757972     50.624569
# 1  EASTERN TEMPERATE FORESTS   2005-09           4.952767     90.424602
# 2  EASTERN TEMPERATE FORESTS   2005-02           2.275852    110.091752
# 3  EASTERN TEMPERATE FORESTS   2005-02           2.275852    110.091752
# 4  EASTERN TEMPERATE FORESTS   2005-02           2.275852    110.091752
#
#    max_air_temp  mean_wind_speed                           geometry
# 0    299.639977         4.281175  POINT (-88.12200000000001 30.383)
# 1    305.166767         3.975596              POINT (-88.301 30.41)
# 2    289.275777         4.016748             POINT (-88.337 30.672)
# 3    289.275777         4.016748  POINT (-87.77200000000001 31.052)
# 4    289.275777         4.016748  POINT (-88.37299999999999 31.101)

# %%
states = states.to_crs(df.crs)
states.head()
# Out:
#                         L1_KEY                         L2_KEY          L3_KEY  \
# 0  7  MARINE WEST COAST FOREST  7.1  MARINE WEST COAST FOREST  1  Coast Range
# 1  7  MARINE WEST COAST FOREST  7.1  MARINE WEST COAST FOREST  1  Coast Range
# 2  7  MARINE WEST COAST FOREST  7.1  MARINE WEST COAST FOREST  1  Coast Range
# 3  7  MARINE WEST COAST FOREST  7.1  MARINE WEST COAST FOREST  1  Coast Range
# 4  7  MARINE WEST COAST FOREST  7.1  MARINE WEST COAST FOREST  1  Coast Range
#
#   NA_L1CODE                 NA_L1NAME NA_L2CODE                 NA_L2NAME  \
# 0         7  MARINE WEST COAST FOREST       7.1  MARINE WEST COAST FOREST
# 1         7  MARINE WEST COAST FOREST       7.1  MARINE WEST COAST FOREST
# 2         7  MARINE WEST COAST FOREST       7.1  MARINE WEST COAST FOREST
# 3         7  MARINE WEST COAST FOREST       7.1  MARINE WEST COAST FOREST
# 4         7  MARINE WEST COAST FOREST       7.1  MARINE WEST COAST FOREST
#
#   NA_L3CODE    NA_L3NAME    Shape_Area     Shape_Leng US_L3CODE    US_L3NAME  \
# 0     7.1.8  Coast Range  1.872044e+09  312708.089755         1  Coast Range
# 1     7.1.8  Coast Range  6.470114e+03     405.107034         1  Coast Range
# 2     7.1.8  Coast Range  4.503063e+05    6693.388907         1  Coast Range
# 3     7.1.8  Coast Range  2.298740e+03     186.667132         1  Coast Range
# 4     7.1.8  Coast Range  1.898114e+03     239.131689         1  Coast Range
#
#                                             geometry
# 0  POLYGON ((-122.4715189587999 37.63402018708508...
# 1  POLYGON ((-123.0025761708425 37.69391604233428...
# 2  POLYGON ((-123.0043472857334 37.70352666575616...
# 3  POLYGON ((-123.0322677712933 37.72801282059357...
# 4  POLYGON ((-123.0985489571485 37.76440585205502...

# %%
ax = states.plot(linewidth=0.25, edgecolor='white', color='lightgrey')
df.plot(markersize=2, alpha=0.25, color='red', ax=ax)
ax.axis('off')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-93-deca7a82435c> in <module>()
#       1 ax = states.plot(linewidth=0.25, edgecolor='white', color='lightgrey')
# ----> 2 df.plot(markersize=2, alpha=0.25, color='red', ax=ax)
#       3 ax.axis('off')
#
# /usr/local/lib/python3.6/site-packages/geopandas/geodataframe.py in plot(self, *args, **kwargs)
#     445     def plot(self, *args, **kwargs):
#     446
# --> 447         return plot_dataframe(self, *args, **kwargs)
#     448
#     449     plot.__doc__ = plot_dataframe.__doc__
#
# /usr/local/lib/python3.6/site-packages/geopandas/plotting.py in plot_dataframe(s, column, cmap, color, linewidth, categorical, legend, ax, scheme, k, vmin, vmax, figsize, **color_kwds)
#     238         return plot_series(s.geometry, cmap=cmap, color=color,
#     239                            ax=ax, linewidth=linewidth, figsize=figsize,
# --> 240                            **color_kwds)
#     241     else:
#     242         if s[column].dtype is np.dtype('O'):
#
# /usr/local/lib/python3.6/site-packages/geopandas/plotting.py in plot_series(s, cmap, color, ax, linewidth, figsize, **color_kwds)
#     145             plot_multilinestring(ax, geom, color=col, linewidth=linewidth, **color_kwds)
#     146         elif geom.type == 'Point':
# --> 147             plot_point(ax, geom, color=col, **color_kwds)
#     148     plt.draw()
#     149     return ax
#
# /usr/local/lib/python3.6/site-packages/geopandas/plotting.py in plot_point(ax, pt, marker, markersize, color, **kwargs)
#      52 def plot_point(ax, pt, marker='o', markersize=2, color='black', **kwargs):
#      53     """ Plot a single Point geometry """
# ---> 54     ax.plot(pt.x, pt.y, marker=marker, markersize=markersize, color=color, **kwargs)
#      55
#      56
#
# /usr/local/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, *args, **kwargs)
#    1896                     warnings.warn(msg % (label_namer, func.__name__),
#    1897                                   RuntimeWarning, stacklevel=2)
# -> 1898             return func(ax, *args, **kwargs)
#    1899         pre_doc = inner.__doc__
#    1900         if pre_doc is None:
#
# /usr/local/lib/python3.6/site-packages/matplotlib/axes/_axes.py in plot(self, *args, **kwargs)
#    1408             lines.append(line)
#    1409
# -> 1410         self.autoscale_view(scalex=scalex, scaley=scaley)
#    1411         return lines
#    1412
#
# /usr/local/lib/python3.6/site-packages/matplotlib/axes/_base.py in autoscale_view(self, tight, scalex, scaley)
#    2264
#    2265         if self.use_sticky_edges and (self._xmargin or self._ymargin):
# -> 2266             stickies = [artist.sticky_edges for artist in self.get_children()]
#    2267             x_stickies = sum([sticky.x for sticky in stickies], [])
#    2268             y_stickies = sum([sticky.y for sticky in stickies], [])
#
# /usr/local/lib/python3.6/site-packages/matplotlib/axes/_base.py in <listcomp>(.0)
#    2264
#    2265         if self.use_sticky_edges and (self._xmargin or self._ymargin):
# -> 2266             stickies = [artist.sticky_edges for artist in self.get_children()]
#    2267             x_stickies = sum([sticky.x for sticky in stickies], [])
#    2268             y_stickies = sum([sticky.y for sticky in stickies], [])
#
# /usr/local/lib/python3.6/site-packages/matplotlib/artist.py in sticky_edges(self)
#     949
#     950         """
# --> 951         return self._sticky_edges
#     952
#     953     def update_from(self, other):
#
# KeyboardInterrupt:

# %%
states_df = gpd.sjoin(df, states, how='left', op='within')
states_df.head()

# %%
ax = states.to_crs({'proj': 'merc'}).plot(color='#cccccc', edgecolor='white', figsize=(7,7))
df.to_crs({'proj': 'merc'}).plot(ax=ax, color='red', markersize=3, alpha=0.5)
ax.axis('off')

# %%
df_84 = df[df['year']== 1984]
df_84

# %%
def make_point(row):
    return Point(row.long, row.lat)
points = df_84.apply(make_point, axis=1)
df_84 = gpd.GeoDataFrame(df_84, geometry=points)
df_84.crs = {'init': 'epsg:4326'}
df_84.head()

# %%
states_84 = states.to_crs(df_84.crs)
states_84.head()

# %%
ax_84 = states_84.plot(linewidth=0.25, edgecolor='white', color='lightgrey')
df_84.plot(markersize=2, alpha=0.25, color='red', ax_84=ax_84)
ax_84.axis('off')

# %%
statesdf_84 = gpd.sjoin(df_84, states_84, how='left', op='within')
statesdf_84.head()

# %%
ax_84 = states_84.to_crs({'proj': 'merc'}).plot(color='#cccccc', edgecolor='white', figsize=(7,7))
df_84.to_crs({'proj': 'merc'}).plot(ax=ax, color='red', markersize=3, alpha=0.5)
ax_84.axis('off')
